# %% [markdown]
# <a href="https://colab.research.google.com/github/Abikelv87/Abikelv87/blob/main/Miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quiz questions stored in a list of dictionaries
quiz_questions = [
    {"question": "What is the capital of cross river?", "answer": "Calabar"},
    {"question": "What is 4 multiplied by 5?", "answer": "20"},
    {"question": "What is the chemical symbol for water?", "answer": "H2O"},
    {"question": "Who wrote 'Romeo and Juliet'?", "answer": "Shakespeare"},
    {"question": "What is the largest planet in our solar system?", "answer": "Jupiter"}
]

score = 0

print("Welcome to the Quiz Game!\n")

for i, item in enumerate(quiz_questions, 1):
    user_answer = input(f"Q{i}: {item['question']} ").strip().lower()
    correct_answer = item["answer"].strip().lower()
    if user_answer == correct_answer:
        print("Correct!\n")
        score += 1
    else:
        print(f"Wrong! The correct answer is: {item['answer']}\n")

print(f"Quiz completed! Your final score is {score} out of {len(quiz_questions)}.")
# Out:
# Welcome to the Quiz Game!

# %% [markdown]
# def swap_numbers():
#     try:
#         # Get input from user
#         num1 = float(input("Enter the first number: "))
#         num2 = float(input("Enter the second number: "))
#
#         # Display before swap
#         print(f"Before swapping: num1 = {num1}, num2 = {num2}")
#
#         # Swap using tuple unpacking
#         num1, num2 = num2, num1
#
#         # Display after swap
#         print(f"After swapping: num1 = {num1}, num2 = {num2}")
#
#     except ValueError:
#         print("Invalid input! Please enter numeric values only.")
#
# # Run the function
# swap_numbers()

# %% [markdown]
# def generate_fibonacci(n):
#     sequence = []
#     a, b = 0, 1
#     for _ in range(n):
#         sequence.append(a)
#         a, b = b, a + b
#     return sequence
#
# def main():
#     try:
#         user_input = input("Enter the number of Fibonacci terms to generate: ")
#         n = int(user_input)
#
#         if n <= 0:
#             print("Error: Please enter a positive integer greater than zero.")
#         else:
#             sequence = generate_fibonacci(n)
#             print(f"The first {n} terms of the Fibonacci sequence are:")
#             print(sequence)
#
#     except ValueError:
#         print("Invalid input. Please enter a valid positive integer.")
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# def is_prime(num):
#     if num <= 1:
#         return False
#     for i in range(2, int(num ** 0.5) + 1):
#         if num % i == 0:
#             return False
#     return True
#
# def is_armstrong(num):
#     digits = [int(d) for d in str(num)]
#     power = len(digits)
#     total = sum([d ** power for d in digits])
#     return total == num
#
# def is_palindrome(num):
#     return str(num) == str(num)[::-1]
#
# def main():
#     try:
#         user_input = input("Enter an integer: ")
#         number = int(user_input)
#
#         results = []
#
#         if is_prime(number):
#             results.append("a Prime number")
#         if is_armstrong(number):
#             results.append("an Armstrong number")
#         if is_palindrome(number):
#             results.append("a Palindrome number")
#
#         if results:
#             print(f"{number} is " + ", ".join(results) + ".")
#         else:
#             print(f"{number} does not meet any criteria.")
#     except ValueError:
#         print("Invalid input. Please enter a valid integer.")
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# # Quiz questions stored in a list of dictionaries
# quiz_questions = [
#     {"question": "What is the capital of cross river?", "answer": "Calabar"},
#     {"question": "What is 4 multiplied by 5?", "answer": "20"},
#     {"question": "What is the chemical symbol for water?", "answer": "H2O"},
#     {"question": "Who wrote 'Romeo and Juliet'?", "answer": "Shakespeare"},
#     {"question": "What is the largest planet in our solar system?", "answer": "Jupiter"}
# ]
#
# score = 0
#
# print("Welcome to the Quiz Game!\n")
#
# for i, item in enumerate(quiz_questions, 1):
#     user_answer = input(f"Q{i}: {item['question']} ").strip().lower()
#     correct_answer = item["answer"].strip().lower()
#     if user_answer == correct_answer:
#         print("Correct!\n")
#         score += 1
#     else:
#         print(f"Wrong! The correct answer is: {item['answer']}\n")
#
# print(f"Quiz completed! Your final score is {score} out of {len(quiz_questions)}.")
